# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = "/Users/sahithi/Desktop/week 4 q@a/Telco-Customer-Churn.xlsx"
df= pd.read_excel(filename)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Compare churn count with respect to gender.

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
list(df.columns)
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
df1 = df.loc[,:]

# %%
male = df['gender'] == 'Male'

# %%
df1 = df.loc[male,:]

# %%
df1
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male            0.0      No         No    34.0
# 2     3668-QPYBK   Male            0.0      No         No     2.0
# 3     7795-CFOCW   Male            0.0      No         No    45.0
# 6     1452-KIOVK   Male            0.0      No        Yes    22.0
# 9     6388-TABGU   Male            0.0      No        Yes    62.0
# ...          ...    ...            ...     ...        ...     ...
# 7033  9767-FFLEM   Male            0.0      No         No    38.0
# 7035  8456-QDAVC   Male            0.0      No         No    19.0
# 7038  6840-RESVB   Male            0.0     Yes        Yes    24.0
# 7041  8361-LTMKD   Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK   Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
female = male = df['gender'] == 'Female'

# %%
df2= df.loc[female,:]

# %%
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# 5     9305-CDSKC  Female            0.0      No         No     8.0
# 7     6713-OKOMC  Female            0.0      No         No    10.0
# 8     7892-POOKP  Female            0.0     Yes         No    28.0
# ...          ...     ...            ...     ...        ...     ...
# 7034  0639-TSIQW  Female            0.0      No         No    67.0
# 7036  7750-EYXWZ  Female            0.0      No         No    12.0
# 7037  2569-WGERO  Female            0.0      No         No    72.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
plt.figure()
plt.hist(df1["churn"])
plt.xticks
plt.yticks
plt.xlabel("churn")
plt.xlabel("male")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'churn'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Find out how many female senior citizens there in the dataset

# %%
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# 5     9305-CDSKC  Female            0.0      No         No     8.0
# 7     6713-OKOMC  Female            0.0      No         No    10.0
# 8     7892-POOKP  Female            0.0     Yes         No    28.0
# ...          ...     ...            ...     ...        ...     ...
# 7034  0639-TSIQW  Female            0.0      No         No    67.0
# 7036  7750-EYXWZ  Female            0.0      No         No    12.0
# 7037  2569-WGERO  Female            0.0      No         No    72.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
senior_citizens  = df['SeniorCitizen'] == 1

# %%
df2= df2.loc[senior_citizens ,:]

# %%
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female            1.0     Yes         No    71.0
# 50    8012-SOUDQ  Female            1.0      No         No    43.0
# 52    6575-SUVOI  Female            1.0     Yes         No    25.0
# 53    7495-OOKFY  Female            1.0     Yes         No     8.0
# 54    4667-QONEA  Female            1.0     Yes        Yes    60.0
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female            1.0     Yes         No    50.0
# 7008  1980-KXVPM  Female            1.0      No         No     3.0
# 7010  0723-DRCLG  Female            1.0     Yes         No     1.0
# 7023  1035-IPQPU  Female            1.0     Yes         No    63.0
# 7029  2235-DWLJU  Female            1.0      No         No     6.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
df2("SeniorCitizen")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df2("SeniorCitizen")
#
# TypeError: 'DataFrame' object is not callable

# %%
df2["Churn"].hist()
# Out:
# <AxesSubplot:>

# %%
df1["Churn"].hist()
# Out:
# <AxesSubplot:>

# %%
[(df2["Churn"]),(df1["Churn"])].hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 [(df2["Churn"]),(df1["Churn"])].hist()
#
# AttributeError: 'list' object has no attribute 'hist'

# %%
plt.figure()
plt.hist((df1["Churn"],df2["Churn"]),label =["male","female",],alpha=0.5)
plt.legend(borderpad= 0.5,fontsize=10)
plt.title("comparison of male and female churns")
plt.show()

# %% [markdown]
# # Compare 'tenure' with 'Total Charges'

# %%
list(df.columns)
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
plt.figure()
plt.hist((df["tenure"],df["Churn"]),label =["male","female",],alpha=0.5)
plt.legend(borderpad= 0.5,fontsize=10)
plt.title("comparison of male and female churns")
plt.show()

# %%
df[['tenure','TotalCharges']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="tenure",y="TotalCharges",data=df)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %%
tenure_df = df1.loc[:,"tenure"].values

# %%
TotalCharges_df = df1.loc[:,"TotalCharges"].values

# %% [markdown]
# # Find out which contract is preferred by the senior citizen.

# %%
sns.countplot(x='Contract', data=df)
plt.title('contract is preferred by the senior citizen')
# Out:
# Text(0.5, 1.0, 'contract is preferred by the senior citizen')

# %%
#month to month contract is preferred by many people

# %% [markdown]
# # Comment on your finds on Payment Method?

# %%
sns.countplot(x='PaymentMethod', data=df)
plt.title('payment methods')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %% [markdown]
# ##most people prefer to pay through ELECTRONIC CHECKS
